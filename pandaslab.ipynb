# %%
import pandas as pd

# %%
data={
    "Name":["Sam","Ravi","Anita"],
    "Age":[25,28,22],
    "City":["Hyderabad","Mumbai","Delhi"]
}
df=pd.DataFrame(data)
print(df)
# Out:
#     Name  Age       City
# 0    Sam   25  Hyderabad
# 1   Ravi   28     Mumbai
# 2  Anita   22      Delhi

# %%
import matplotlib.pyplot as plt
df=pd.read_csv("csa_b.csv")
print(df)
# Out:
#     Roll_no  SAC_Marks
# 0        67         80
# 1        68         74
# 2        69         51
# 3        70         28
# 4        71         91
# 5        72         62
# 6        73         73
# 7        74         54
# 8        75         43
# 9        76         62
# 10       77         52
# 11       78         29
# 12       79         45
# 13       80         87
# 14       81         81
# 15       82         50
# 16       83         64
# 17       84         59
# 18       85        100
# 19       86         30
# 20       87         60
# 21       88         67
# 22       89         62
# 23       90         92
# 24       91         68
# 25       92         73
# 26       93         75
# 27       94         84
# 28       95         65
# 29       96         81

# %% [markdown]
# # line plot

# %%
df['SAC_Marks'].plot(kind="line")
plt.title("Line Plot")
plt.show()

# %% [markdown]
# # bar plot

# %%
df['SAC_Marks'].plot(kind="bar")
plt.title("Bar Plot")
plt.show()

# %%
df.plot(kind='bar',x="Roll_no",y="SAC_Marks")
# Out:
# <Axes: xlabel='Roll_no'>

# %% [markdown]
# # Box plot

# %%
df['SAC_Marks'].plot(kind="box")
plt.title("Box Plot")
plt.show()

# %% [markdown]
# # histogram

# %%
df['SAC_Marks'].plot(kind="hist")
plt.title("Histogram")
plt.show()
